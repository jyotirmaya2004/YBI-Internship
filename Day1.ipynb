# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotirmaya2004/YBI-Internship/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Declare variables

# %%
a=5
b=3.14
c=2+3j

print(a,b,c)
# Out:
# 5 3.14 (2+3j)

# %% [markdown]
# ## Bollen variables

# %%
a=True
b=False

x=(10>5)
y=(7==3)
print(a,b)
print(x,y)
# Out:
# True False
# True False

# %% [markdown]
# ## Creating list variable

# %%
a=[1,2,3]
b=["apple","banana","Mango"]
c=[1,"hello",3.5]
d=[]
print(a)
print(b)
print(c)
print(d)
# Out:
# [1, 2, 3]
# ['apple', 'banana', 'Mango']
# [1, 'hello', 3.5]
# []

# %% [markdown]
# ## Creataing a Tupple variable

# %%
a=(1,2,3)
b=("apple","banana","mango")
c=(1,"hello",3.5)
d=(5,)
e=()
f=12,32,21
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
# Out:
# (1, 2, 3)
# ('apple', 'banana', 'mango')
# (1, 'hello', 3.5)
# (5,)
# ()
# (12, 32, 21)

# %% [markdown]
# ## Creating Set variables

# %%
a={1,2,3}
b={"apple","banana","mango"}
c={1,"hello,3.5"}
d=set()
print(a)
print(b)
print(c)
print(d)
# Out:
# {1, 2, 3}
# {'banana', 'apple', 'mango'}
# {1, 'hello,3.5'}
# set()

# %% [markdown]
# ## Creating dictionary variables

# %%
a={"name":"Alice","age":25}
b={"a":1,"b":2,"c":3}
c={1:"one",2:"two"}
d={}

print(a)
print(b)
print(c)
print(d)
# Out:
# {'name': 'Alice', 'age': 25}
# {'a': 1, 'b': 2, 'c': 3}
# {1: 'one', 2: 'two'}
# {}

# %% [markdown]
# ## Accepting inputs from console

# %%
name= input("Enter your name : ")
age= input ("Enter your age : ")
print(name)
print(age)
# Out:
# Enter your name : jyotirmaya
# Enter your age : 21
# jyotirmaya
# 21
